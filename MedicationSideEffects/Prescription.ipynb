# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('./drugs_side_effects_drugs_com.csv')

# %%
dataset.shape
# Out:
# (2931, 17)

# %%
dataset.drug_name.value_counts()
# Out:
# drug_name
# triamcinolone                                      3
# fluticasone                                        2
# acyclovir                                          2
# hydrocortisone                                     2
# diclofenac                                         2
#                                                   ..
# Contac Cold + Flu (Night) Cooling Relief Liquid    1
# Dallergy                                           1
# Dallergy Drops                                     1
# Decorel Forte Plus                                 1
# setmelanotide                                      1
# Name: count, Length: 2912, dtype: int64

# %%
dataset.drug_name.unique().shape
# Out:
# (2912,)

# %%
dataset.medical_condition.unique()
# Out:
# array(['Acne', 'ADHD', 'AIDS/HIV', 'Allergies', "Alzheimer's", 'Angina',
#        'Anxiety', 'Asthma', 'Bipolar Disorder', 'Bronchitis', 'Cancer',
#        'Cholesterol', 'Colds & Flu', 'Constipation', 'COPD', 'Covid 19',
#        'Depression', 'Diabetes (Type 1)', 'Diabetes (Type 2)', 'Diarrhea',
#        'Eczema', 'Erectile Dysfunction', 'Gastrointestinal',
#        'GERD (Heartburn)', 'Gout', 'Hair Loss', 'Hayfever', 'Herpes',
#        'Hypertension', 'Hypothyroidism', 'IBD (Bowel)', 'Incontinence',
#        'Insomnia', 'Menopause', 'Migraine', 'Osteoarthritis',
#        'Osteoporosis', 'Pain', 'Pneumonia', 'Psoriasis',
#        'Rheumatoid Arthritis', 'Schizophrenia', 'Seizures', 'Stroke',
#        'Swine Flu', 'UTI', 'Weight Loss'], dtype=object)

# %%
dataset.head(5)
# Out:
#         drug_name medical_condition  \
# 0     doxycycline              Acne
# 1  spironolactone              Acne
# 2     minocycline              Acne
# 3        Accutane              Acne
# 4     clindamycin              Acne
#
#                                         side_effects         generic_name  \
# 0  (hives, difficult breathing, swelling in your ...          doxycycline
# 1  hives ; difficulty breathing; swelling of your...       spironolactone
# 2  skin rash, fever, swollen glands, flu-like sym...          minocycline
# 3  problems with your vision or hearing; muscle o...  isotretinoin (oral)
# 4  hives ; difficult breathing; swelling of your ...  clindamycin topical
#
#                                         drug_classes  \
# 0         Miscellaneous antimalarials, Tetracyclines
# 1  Aldosterone receptor antagonists, Potassium-sp...
# 2                                      Tetracyclines
# 3  Miscellaneous antineoplastics, Miscellaneous u...
# ...

# %%
dataset.medical_condition.value_counts()
# Out:
# medical_condition
# Pain                    264
# Colds & Flu             245
# Acne                    238
# Hypertension            177
# Osteoarthritis          129
# Hayfever                124
# Eczema                  122
# AIDS/HIV                109
# Diabetes (Type 2)       104
# Psoriasis                93
# GERD (Heartburn)         77
# Pneumonia                72
# Angina                   71
# Bronchitis               71
# Migraine                 61
# Insomnia                 60
# Constipation             60
# Diabetes (Type 1)        57
# Osteoporosis             56
# ADHD                     55
# Depression               51
# Seizures                 50
# Bipolar Disorder         47
# UTI                      46
# Asthma                   45
# Anxiety                  45
# Cholesterol              45
# Diarrhea                 38
# Covid 19                 34
# Rheumatoid Arthritis     33
# Alzheimer's              27
# Weight Loss              23
# ...

# %%
dataset.side_effects.value_counts()
# Out:
# side_effects
# hives ; difficult breathing; swelling of your face, lips, tongue, or throat. This medicine may cause serious side effects. Stop using this medicine and call your doctor at once if you have: redness or swelling of the treated area; increased pain; or severe burning or skin irritation such as a rash, itching, pain, or blistering. Less serious side effects may be more likely, and you may have none at all.                                                                                                                                                                                                                                                                                                                                                                                                                                                                    10
# ...

# %%
dataset.medical_condition.value_counts()
# Out:
# medical_condition
# Pain                    264
# Colds & Flu             245
# Acne                    238
# Hypertension            177
# Osteoarthritis          129
# Hayfever                124
# Eczema                  122
# AIDS/HIV                109
# Diabetes (Type 2)       104
# Psoriasis                93
# GERD (Heartburn)         77
# Pneumonia                72
# Angina                   71
# Bronchitis               71
# Migraine                 61
# Insomnia                 60
# Constipation             60
# Diabetes (Type 1)        57
# Osteoporosis             56
# ADHD                     55
# Depression               51
# Seizures                 50
# Bipolar Disorder         47
# UTI                      46
# Asthma                   45
# Anxiety                  45
# Cholesterol              45
# Diarrhea                 38
# Covid 19                 34
# Rheumatoid Arthritis     33
# Alzheimer's              27
# Weight Loss              23
# ...

# %%
dataset.side_effects
# Out:
# 0       (hives, difficult breathing, swelling in your ...
# 1       hives ; difficulty breathing; swelling of your...
# 2       skin rash, fever, swollen glands, flu-like sym...
# 3       problems with your vision or hearing; muscle o...
# 4       hives ; difficult breathing; swelling of your ...
#                               ...
# 2926    hives ; difficulty breathing; swelling of your...
# 2927    hives ; difficult breathing; swelling of your ...
# 2928                                                  NaN
# 2929    Imcivree may cause serious side effects, inclu...
# 2930    hives ; difficult breathing; swelling of your ...
# Name: side_effects, Length: 2931, dtype: object

# %%
dataset['generic_name']=dataset['generic_name'].str.lower()
dataset['medical_condition']=dataset['medical_condition'].str.lower()
dataset['side_effects']=dataset['side_effects'].str.lower()
dataset['drug_name']=dataset['drug_name'].str.lower()

# %%
dataset.head(5)
# Out:
#         drug_name medical_condition  \
# 0     doxycycline              acne
# 1  spironolactone              acne
# 2     minocycline              acne
# 3        accutane              acne
# 4     clindamycin              acne
#
#                                         side_effects         generic_name  \
# 0  (hives, difficult breathing, swelling in your ...          doxycycline
# 1  hives ; difficulty breathing; swelling of your...       spironolactone
# 2  skin rash, fever, swollen glands, flu-like sym...          minocycline
# 3  problems with your vision or hearing; muscle o...  isotretinoin (oral)
# 4  hives ; difficult breathing; swelling of your ...  clindamycin topical
#
#                                         drug_classes  \
# 0         Miscellaneous antimalarials, Tetracyclines
# 1  Aldosterone receptor antagonists, Potassium-sp...
# 2                                      Tetracyclines
# 3  Miscellaneous antineoplastics, Miscellaneous u...
# ...

# %%
dataset['side_effects'] = dataset['side_effects'].astype(str)

# %%
pip install tensorflow_hub
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# import tensorflow as tf       # To work with USE4
# import pandas as pd           # To work with tables 
# import tensorflow_hub as hub  # contains USE4
# module_url = "https://tfhub.dev/google/universal-sentence-encoder/4" #Model is imported from this URL
# model = hub.load(module_url)
# def embed(input):
#   return model(input)

# %% [markdown]
# ## Check from here

# %%
user_input = input("Enter your Side Effects: ")

# %%
user_input = user_input.lower()

# %%
# from numpy import dot                                           # to calculate the dot product of two vectors
# from numpy.linalg import norm                                   #for finding the norm of a vector

# ans = []                                                        # This list will contain the cosin similarity value for each vector pair present.
# for i in range(len(dataset)):
#   messages = [dataset['side_effects'][i], user_input]  
#   print(i)             #storing each sentence pair in messages
#   message_embeddings = embed(messages)   
#   print("hello")                       #converting the sentence pair to vector pair using the embed() function
#   a = tf.make_ndarray(tf.make_tensor_proto(message_embeddings)) #storing the vector in the form of numpy array
#   cos_sim = dot(a[0], a[1])/(norm(a[0])*norm(a[1]))             #Finding the cosine between the two vectors
#   ans.append(cos_sim)                                           #Appending the values into the ans list

# %%
# Ans = pd.DataFrame(ans, columns = ['Similarity_Score'])

# %%
# Ans

# %%
pip install spacy
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip3 install -U spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 199.8 kB/s eta 0:00:0000:0100:02
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# import spacy
# nlp = spacy.load("en_core_web_sm")
# doc = nlp("This is a sentence.")
# print([(w.text, w.pos_) for w in doc])

# %%
import spacy
import numpy as np
# Load the spaCy English model
nlp = spacy.load("en_core_web_sm")

# Define a function to calculate the cosine similarity between two sentences
def calculate_cosine_similarity(sentence1, sentence2):
  """Calculates the cosine similarity between two sentences.

  Args:
    sentence1: A string representing the first sentence.
    sentence2: A string representing the second sentence.

  Returns:
    A float representing the cosine similarity between the two sentences.
  """

  # Tokenize the sentences
  tokens1 = nlp(sentence1)
  tokens2 = nlp(sentence2)

  # Calculate the sentence embeddings
  sentence_embedding1 = tokens1.vector
  sentence_embedding2 = tokens2.vector

  # Calculate the cosine similarity


# Assuming sentence_embedding1 and sentence_embedding2 are NumPy arrays or lists
  cosine_similarity = np.dot(sentence_embedding1, sentence_embedding2) / (
    np.linalg.norm(sentence_embedding1) * np.linalg.norm(sentence_embedding2)
  )


  return cosine_similarity

# Example usage:

# sentence1 = "The cat sat on the mat."
# sentence2 = "The feline rested on the rug."

# # Calculate the cosine similarity between the two sentences
# cosine_similarity = calculate_cosine_similarity(sentence1, sentence2)

# # Print the cosine similarity
# print(cosine_similarity)
# Out:
# 0.8600918

# %%
# ans = []                                                        # This list will contain the cosin similarity value for each vector pair present.
# for i in range(len(dataset)):
#   messages = [dataset['side_effects'][i], user_input]  
#   print(i)             #storing each sentence pair in messages
#   message_embeddings = embed(messages)   
#   print("hello")                       #converting the sentence pair to vector pair using the embed() function
#   a = tf.make_ndarray(tf.make_tensor_proto(message_embeddings)) #storing the vector in the form of numpy array
#   cos_sim = dot(a[0], a[1])/(norm(a[0])*norm(a[1]))             #Finding the cosine between the two vectors
#   ans.append(cos_sim)                                           #Appending the values into the ans list

# %%
# Out:
# [['Alice', 100], ['Bob', 200], ['Carol', 300]]

# %%
ans = []
sim_score = []
activity = []
for i in range(len(dataset)):
    sentence1 = dataset['side_effects'][i]
    sentence2 = user_input
    cosine_similarity = calculate_cosine_similarity(sentence1, sentence2)
    # print(cosine_similarity)
    if cosine_similarity > 0.5:
        ans.append(dataset['generic_name'][i])
        sim_score.append(cosine_similarity)
        activity.append(dataset['activity'][i])
# Out:
# 0.58082473
# 0.63214934
# 0.55237424
# 0.57580775
# 0.47564963
# 0.62584907
# 0.471238
# 0.5707233
# 0.578718
# 0.46333674
# 0.4683929
# 0.42098382
# 0.50934947
# 0.4456494
# 0.4953098
# 0.5144827
# 0.36811945
# 0.49729005
# 0.58729523
# 0.5669944
# 0.51916385
# 0.36795035
# 0.4888615
# 0.38360843
# 0.51199394
# 0.51053673
# 0.5719877
# 0.3978562
# 0.36671835
# 0.48364863
# 0.4859094
# 0.36756834
# 0.36811915
# 0.36909416
# 0.48300347
# 0.3645992
# 0.4697959
# 0.47451353
# 0.3686034
# 0.47577262
# 0.48891735
# 0.48555443
# 0.57117045
# 0.3215209
# 0.4467038
# 0.34494296
# 0.54845023
# 0.42758247
# 0.49300274
# 0.5187291
# 0.32055587
# 0.32086572
# 0.31368706
# 0.46781057
# 0.3645464
# 0.5718424
# 0.47103438
# 0.571347
# 0.40221894
# 0.57107294
# 0.49722213
# 0.22434346
# 0.46377036
# 0.3860618
# 0.48396924
# 0.45483425
# 0.48309442
# 0.22434346
# 0.56946653
# 0.39894524
# 0.47273734
# 0.4496093
# 0.22434346
# 0.4940187
# 0.4883219
# 0.22434346
# 0.498856
# 0.28798118
# 0.49567646
# ...

# %%
for i in range(len(ans)):
    print(f"Drug Name: {ans[i]}, Probability: {sim_score[i]}, Overall Activity of the Drug: {activity[i]}")
# Out:
# Drug Name: doxycycline, Probability: 0.5808247327804565, Overall Activity of the Drug: 87%
# Drug Name: spironolactone, Probability: 0.632149338722229, Overall Activity of the Drug: 82%
# Drug Name: minocycline, Probability: 0.5523742437362671, Overall Activity of the Drug: 48%
# Drug Name: isotretinoin (oral), Probability: 0.5758077502250671, Overall Activity of the Drug: 41%
# Drug Name: spironolactone, Probability: 0.6258490681648254, Overall Activity of the Drug: 35%
# Drug Name: isotretinoin (oral), Probability: 0.570723295211792, Overall Activity of the Drug: 26%
# Drug Name: sulfamethoxazole and trimethoprim, Probability: 0.5787180066108704, Overall Activity of the Drug: 20%
# Drug Name: adapalene topical, Probability: 0.5093494653701782, Overall Activity of the Drug: 12%
# Drug Name: cephalexin, Probability: 0.5144826769828796, Overall Activity of the Drug: 9%
# ...
