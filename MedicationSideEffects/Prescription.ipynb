# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('./drugs_side_effects_drugs_com.csv')

# %%
dataset.shape
# Out:
# (2931, 17)

# %%
dataset.drug_name.value_counts()
# Out:
# drug_name
# triamcinolone                                      3
# fluticasone                                        2
# acyclovir                                          2
# hydrocortisone                                     2
# diclofenac                                         2
#                                                   ..
# Contac Cold + Flu (Night) Cooling Relief Liquid    1
# Dallergy                                           1
# Dallergy Drops                                     1
# Decorel Forte Plus                                 1
# setmelanotide                                      1
# Name: count, Length: 2912, dtype: int64

# %%
dataset.drug_name.unique().shape
# Out:
# (2912,)

# %%
dataset.head(5)
# Out:
#         drug_name medical_condition  \
# 0     doxycycline              Acne
# 1  spironolactone              Acne
# 2     minocycline              Acne
# 3        Accutane              Acne
# 4     clindamycin              Acne
#
#                                         side_effects         generic_name  \
# 0  (hives, difficult breathing, swelling in your ...          doxycycline
# 1  hives ; difficulty breathing; swelling of your...       spironolactone
# 2  skin rash, fever, swollen glands, flu-like sym...          minocycline
# 3  problems with your vision or hearing; muscle o...  isotretinoin (oral)
# 4  hives ; difficult breathing; swelling of your ...  clindamycin topical
#
#                                         drug_classes  \
# 0         Miscellaneous antimalarials, Tetracyclines
# 1  Aldosterone receptor antagonists, Potassium-sp...
# 2                                      Tetracyclines
# 3  Miscellaneous antineoplastics, Miscellaneous u...
# ...

# %%
dataset.medical_condition.value_counts()
# Out:
# medical_condition
# Pain                    264
# Colds & Flu             245
# Acne                    238
# Hypertension            177
# Osteoarthritis          129
# Hayfever                124
# Eczema                  122
# AIDS/HIV                109
# Diabetes (Type 2)       104
# Psoriasis                93
# GERD (Heartburn)         77
# Pneumonia                72
# Angina                   71
# Bronchitis               71
# Migraine                 61
# Insomnia                 60
# Constipation             60
# Diabetes (Type 1)        57
# Osteoporosis             56
# ADHD                     55
# Depression               51
# Seizures                 50
# Bipolar Disorder         47
# UTI                      46
# Asthma                   45
# Anxiety                  45
# Cholesterol              45
# Diarrhea                 38
# Covid 19                 34
# Rheumatoid Arthritis     33
# Alzheimer's              27
# Weight Loss              23
# ...

# %%
dataset.side_effects.value_counts()
# Out:
# side_effects
# hives ; difficult breathing; swelling of your face, lips, tongue, or throat. This medicine may cause serious side effects. Stop using this medicine and call your doctor at once if you have: redness or swelling of the treated area; increased pain; or severe burning or skin irritation such as a rash, itching, pain, or blistering. Less serious side effects may be more likely, and you may have none at all.                                                                                                                                                                                                                                                                                                                                                                                                                                                                    10
# ...

# %%
dataset.medical_condition.value_counts()
# Out:
# medical_condition
# Pain                    264
# Colds & Flu             245
# Acne                    238
# Hypertension            177
# Osteoarthritis          129
# Hayfever                124
# Eczema                  122
# AIDS/HIV                109
# Diabetes (Type 2)       104
# Psoriasis                93
# GERD (Heartburn)         77
# Pneumonia                72
# Angina                   71
# Bronchitis               71
# Migraine                 61
# Insomnia                 60
# Constipation             60
# Diabetes (Type 1)        57
# Osteoporosis             56
# ADHD                     55
# Depression               51
# Seizures                 50
# Bipolar Disorder         47
# UTI                      46
# Asthma                   45
# Anxiety                  45
# Cholesterol              45
# Diarrhea                 38
# Covid 19                 34
# Rheumatoid Arthritis     33
# Alzheimer's              27
# Weight Loss              23
# ...

# %%
dataset.side_effects
# Out:
# 0       (hives, difficult breathing, swelling in your ...
# 1       hives ; difficulty breathing; swelling of your...
# 2       skin rash, fever, swollen glands, flu-like sym...
# 3       problems with your vision or hearing; muscle o...
# 4       hives ; difficult breathing; swelling of your ...
#                               ...
# 2926    hives ; difficulty breathing; swelling of your...
# 2927    hives ; difficult breathing; swelling of your ...
# 2928                                                  NaN
# 2929    Imcivree may cause serious side effects, inclu...
# 2930    hives ; difficult breathing; swelling of your ...
# Name: side_effects, Length: 2931, dtype: object

# %%
dataset['medical_condition']=dataset['medical_condition'].str.lower()

# %%
dataset.head(5)
# Out:
#         drug_name medical_condition  \
# 0     doxycycline              acne
# 1  spironolactone              acne
# 2     minocycline              acne
# 3        Accutane              acne
# 4     clindamycin              acne
#
#                                         side_effects         generic_name  \
# 0  (hives, difficult breathing, swelling in your ...          doxycycline
# 1  hives ; difficulty breathing; swelling of your...       spironolactone
# 2  skin rash, fever, swollen glands, flu-like sym...          minocycline
# 3  problems with your vision or hearing; muscle o...  isotretinoin (oral)
# 4  hives ; difficult breathing; swelling of your ...  clindamycin topical
#
#                                         drug_classes  \
# 0         Miscellaneous antimalarials, Tetracyclines
# 1  Aldosterone receptor antagonists, Potassium-sp...
# 2                                      Tetracyclines
# 3  Miscellaneous antineoplastics, Miscellaneous u...
# ...

# %%
drug_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 drug_list
#
# NameError: name 'drug_list' is not defined

# %%
user_input = input("Enter your problem: ")

# %%
user_input = user_input.lower()

# %%
info = dataset[dataset['medical_condition'] == user_input].value_counts()

# %%
info
# Out:
# drug_name                                                medical_condition  side_effects                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              
# ...

# %%
info = dataset[dataset['medical_condition'] == user_input]

# %%
info
# Out:
#           drug_name medical_condition  \
# 0       doxycycline              acne
# 1    spironolactone              acne
# 2       minocycline              acne
# 3          Accutane              acne
# 4       clindamycin              acne
# ..              ...               ...
# 233     Vanoxide-HC              acne
# 234         Winlevi              acne
# 235      Z-Clinz 10              acne
# 236           Zarah              acne
# 237     Zumandimine              acne
#
#                                           side_effects  \
# 0    (hives, difficult breathing, swelling in your ...
# 1    hives ; difficulty breathing; swelling of your...
# 2    skin rash, fever, swollen glands, flu-like sym...
# 3    problems with your vision or hearing; muscle o...
# 4    hives ; difficult breathing; swelling of your ...
# ..                                                 ...
# 233  Stop using this medicine and get emergency med...
# ...

# %%
for i,j in info[['drug_name','generic_name']].values:
    print(f"Drug Name: {i} & Generic Name: {j}")
# Out:
# Drug Name: doxycycline & Generic Name: doxycycline
# Drug Name: spironolactone & Generic Name: spironolactone
# Drug Name: minocycline & Generic Name: minocycline
# Drug Name: Accutane & Generic Name: isotretinoin (oral)
# Drug Name: clindamycin & Generic Name: clindamycin topical
# Drug Name: Aldactone & Generic Name: spironolactone
# Drug Name: tretinoin & Generic Name: tretinoin topical
# Drug Name: isotretinoin & Generic Name: isotretinoin (oral)
# Drug Name: Bactrim & Generic Name: sulfamethoxazole and trimethoprim
# Drug Name: Retin-A & Generic Name: Retin-A
# Drug Name: Aczone & Generic Name: dapsone topical
# Drug Name: benzoyl peroxide & Generic Name: benzoyl peroxide topical
# Drug Name: Differin & Generic Name: adapalene topical
# Drug Name: Epiduo & Generic Name: adapalene and benzoyl peroxide (topical)
# Drug Name: adapalene & Generic Name: adapalene topical
# Drug Name: cephalexin & Generic Name: cephalexin
# Drug Name: Doryx & Generic Name: doxycycline (oral route)
# ...

# %%
#info['side_effects'] = info.side_effects.str.lower()

# %%
#delete duplicate string values in a column 
info['side_effects'] = info['side_effects'].drop_duplicates()
# Out:
# /var/folders/xt/j_t2r08154jgrm4pw6xyzcnr0000gn/T/ipykernel_2039/2707625213.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info['side_effects'] = info['side_effects'].drop_duplicates()

# %%
info['side_effects'].value_counts()
# Out:
# side_effects
# ...

# %%
for i in info[['side_effects']].values:
    print(f"Common Side Effects: {i}")
# Out:
# Common Side Effects: ['(hives, difficult breathing, swelling in your face or throat) or a severe skin reaction (fever, sore throat, burning in your eyes, skin pain, red or purple skin rash that spreads and causes blistering and peeling). Seek medical treatment if you have a serious drug reaction that can affect many parts of your body. Symptoms may include: skin rash, fever, swollen glands, flu-like symptoms, muscle aches, severe weakness, unusual bruising, or yellowing of your skin or eyes. This reaction may occur several weeks after you began using doxycycline. Doxycycline may cause serious side effects. Call your doctor at once if you have: severe stomach pain, diarrhea that is watery or bloody; throat irritation, trouble swallowing; chest pain, irregular heart rhythm, feeling short of breath; little or no urination; low white blood cell counts - fever, chills, swollen glands, body aches, weakness, pale skin, easy bruising or bleeding; severe headaches, ringing in your ears, dizzi
# ...

# %%
drug_input = input("Enter the drug name: ")

# %%
dataset[dataset['drug_name'] == drug_input].side_effects.value_counts()
# Out:
# side_effects
# hives ; difficulty breathing; swelling of your face, lips, tongue, or throat. Call your doctor at once if you have: a light-headed feeling, like you might pass out; little or no urination; high potassium level - nausea , weakness, tingly feeling, chest pain, irregular heartbeats, loss of movement; o signs of other electrolyte imbalances - increased thirst or urination, confusion, vomiting , muscle pain, slurred speech, severe weakness, numbness , loss of coordination, feeling unsteady. Common spironolactone side effects may include: breast swelling or tenderness.    1
# Name: count, dtype: int64

# %%
dataset[dataset['drug_name'] == drug_input].value_counts()
# Out:
# drug_name       medical_condition  side_effects                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               generic_name    drug_classes                                                   brand_names          activity  rx_otc  pregnancy_category  csa  alcohol  related_drugs                                                                                                                                                                                                                                   
# ...
